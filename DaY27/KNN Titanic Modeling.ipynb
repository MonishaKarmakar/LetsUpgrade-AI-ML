# %% [markdown]
# ### Objective- To perform KNN in Titanic Dataset.

# %%
#importing all necessary library
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\Users\DELL\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
#importing the dataset.
dataset=pd.read_csv("Titanic_train.csv")
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          887         0       2
# 885          888         1       1
# 886          889         0       3
# 887          890         1       1
# 888          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
#    **Note:**
#    1. The varibale like **PassengerId, Name, Ticket, Cabin** Can be dropped.
#    2. The Variable like Gender and Embarked can be converted to numeric.

# %%
#Dropping the unnecessary columns
dataset=dataset.drop(['PassengerId','Name','Ticket','Cabin'],axis=1)
dataset.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
#Encoding the categoraical to numeric variable
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
dataset["Sex"]=le.fit_transform(dataset["Sex"])
dataset["Embarked"]=le.fit_transform(dataset["Embarked"])
dataset.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    1  22.0      1      0   7.2500         2
# 1         1       1    0  38.0      1      0  71.2833         0
# 2         1       3    0  26.0      0      0   7.9250         2
# 3         1       1    0  35.0      1      0  53.1000         2
# 4         0       3    1  35.0      0      0   8.0500         2

# %%
#Checking for presence of any null value
dataset.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# ### Defining Function to measure the Accuracy and Confusion matrix

# %%
def fun_model(a,b):
    # For Calculating the accuracy and Confusion Matrix
    from sklearn.model_selection import train_test_split
    from sklearn.metrics import accuracy_score, confusion_matrix
    from sklearn import neighbors
    x_train,x_test,y_train,y_test=train_test_split(a,b,test_size=0.3,random_state=0)
    s=(x_test.shape[0])+1
    for k in range(1,s):
        knn=neighbors.KNeighborsClassifier(n_neighbors=k)
        knn.fit(x_train,y_train).score(x_test,y_test)
        y_pred=knn.predict(x_test)
        print("Preformance Matric for model with k=",k,"is:")
        print("Accuracy Score is",accuracy_score(y_test,y_pred,normalize=True))
        print("The Confusion Matrix is \n",confusion_matrix(y_test,y_pred))

# %%
#Assinging the x and y variable
y=dataset.iloc[:,:1]
y.head()
# Out:
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
x=dataset.drop(['Survived'],axis=1)
x.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0       3    1  22.0      1      0   7.2500         2
# 1       1    0  38.0      1      0  71.2833         0
# 2       3    0  26.0      0      0   7.9250         2
# 3       1    0  35.0      1      0  53.1000         2
# 4       3    1  35.0      0      0   8.0500         2

# %%
#Calling the defined function.
fun_model(x,y)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# ...
