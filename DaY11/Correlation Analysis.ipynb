# %% [markdown]
# # Correlation Analysis of attrition with different variables

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame, read_csv
f = 'C:/Users/DELL/Documents/LetsUpgrade/AL-MI/DaY11/MasterData.csv'
df = read_csv(f)
df=df[:]
df.describe()
print(df)
df.corr()

# %%
df1=df[df["Attrition"] =="Yes"]
df2=df[df["Attrition"] =="No"]
print(len(df1),len(df2))
print(df1)
df1.corr()
# Out:
# 711 3699
#       Age Attrition     BusinessTravel              Department  \
# 1      31       Yes  Travel_Frequently  Research & Development
# 6      28       Yes      Travel_Rarely  Research & Development
# 13     47       Yes         Non-Travel  Research & Development
# 28     44       Yes  Travel_Frequently  Research & Development
# 30     26       Yes      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4381   29       Yes      Travel_Rarely  Research & Development
# 4386   33       Yes      Travel_Rarely                   Sales
# 4388   33       Yes      Travel_Rarely                   Sales
# 4391   32       Yes      Travel_Rarely                   Sales
# 4402   37       Yes  Travel_Frequently                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 1                   10          1  Life Sciences              1           2
# ...

# %% [markdown]
# # Interpretation
#
# ### upon analysis of different variables correlation where the correlation value is more than 0.05 the following has been found:
# #### 1. Age shows postive correlation with NumCompaniesWorked, TotalWorkingYears, YearsAtCompany,YearsSinceLastPromotion, YearsWithCurrManager
# #### 2.DistanceFromHome shows postive correlation with PercentSalaryHike, YearsAtCompany, YearsWithCurrManager
# #### 3.Education shows postive correlation with JobLevel, NumCompaniesWorked,TotalWorkingYears, TrainingTimesLastYear
# #### 4. MonthlyIncome shows postive correlation with StockOptionLevel
# #### 5. NumCompaniesWorked shows postive correlation with TotalWorkingYears
# #### 6. StockOptionLevel shows postive correlation with YearsAtCompany, YearsWithCurrManager, TotalWorkingYear s
# #### 7. TotalWorkingYears shows postive correlation with YearsAtCompany, YearsSinceLastPromotion, YearsWithCurrManager
# #### 8.  YearsAtCompany shows postive correlation with YearsSinceLastPromotion 	YearsWithCurrManager
# #### 9. YearsSinceLastPromotion shows postive correlation with  YearsWithCurrManager
